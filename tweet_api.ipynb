# %%
import tweepy #https://github.com/tweepy/tweepy
import csv
import json
#Twitter API credentials
consumer_key = "7N4CXqchPcdnVAJZUXDvuykUy"
consumer_secret = "ilWJp0X7yQgiW2dfs1yDeYWbQSdmCyw52TdrJduIacFMoFswMT"
access_key = "1114199493510074368-0Wcf3VwAUpEMiXEk286Ho9mFxFSD59"
access_secret = "qtUk7ovCAMiN0kc93tuuEHFvunywcHiKFSKOrWNj2oFLF"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True, compression=True)

user_name_neg = ['AbbyChe88615215', 'QzI2jJcBFlZmomK', 'sonjahahn', 'Melectroner', 'barcemo2', 'Noahgreenberg12', 'AngelLadyVenus', 'Sagar59781359', 'timarajae', 'Moaz80334541', 'ppmax17', 'LOVE_Raelian', 'SchieblerXavier', 'nazwanazwanazwa', 'DevrajBelgaonk1', 'MatyalAzher', 'kingsugenius', 'greyeaglespouch', 'max_cardaci', 'klmgorov', 'rohitpandya31', 'ctominay', 'imsmruti', 'Bogdan40542498', 'Zeeshan01344758', 'AdamarisVelez', '1uEkvO6odBsDImj', 'MariannaGardar1', 'MelAlex97543906', 'valtomsgv', 'jackrow94480700', 'Domi9915', 'LGszHBzn6H9Aoec', 'QunNguy81644285', 'dblank64', 'MuhammadGhozy9', 'adedivision', 'Frank91806042', 'Seb57466842', 'HYnYang1999', 'KhengKouy', 'Saqlainsharif14', 'Raphael79724082', 'WisdomOgbonna12', 'karthikadr1', 'ibrahemka93', 'artemisia_annie', 'njtktm', 'BJ_Timson', 'MhHoussem', 'Owenchoi9', 'IdrisRockingidd', 'eHo9gixZa47kwcW', 'VickyGo13', 'IdreesAshrafMir', 'P4NT2', 'ICaldicott', 'gabi_emeli', 'LoRaine_fr', 'MarwaanWilliam1', 'StanWoodman4', 'FPrefekt', 'DevPate71188540', '7aDOxFkBKvyfl6', '__Nadeeka', 'priyankamoorthy', 'VivekPa63657629', 'dicksuck4money', 'shai_trakz', 'badal_khosla', 'SwapnilDurgeka1', 'barry_member', 'tsaharsharaf', 'SudipSi66921834', 'ColinCa42350619', 'JoeChen56203494', 'HapuNipuna', 'Whatsup65692095', 'mestevper4mance', 'AasimMushtaq10', 'CamilloGasparri', 'ZachFre06174485', 'Kien12092440', 'VRocchis', 'Charlie_WWright', 'Mathewsmutale9', 'Joshau72077726', 'benbetterb', 'indiana11011100', 'Pavan28843768', 'Andreaarman1', 'CoombesF', 'Soumy21134508', 'nadinelivgmail1', 'ChaudharyAvin', 'LoApa15', 'rachit_mangal', 'SooryanRajeev', 'AbhilashO8', 'aatrees', 'Muham83137969', 'RouelAndrew', 'ModiboDilika', 'LindaSouv', 'TommyTurkia', 'Griee4', 't_elevs', 'immeet6','tc_terps', 'kenji_mugenken', 'gthom15', 'JkrossNoah', 'iholpbrasil', 'A_S_Elgarhy', 'jorgefloresveja', 'Michaelsharp_22', 'DepressedTrans1', 'andrewgalvin20', 'kat_xue', 'syed_javid10', 'zeynepaygunx', 'Magneycostasil1', 'marinasangelo', 'darkwolfgurl96', 'adriankamalian', 'NemoLgh', 'bwilsonjolly', 'terrimcclinton3', 'Eddieironfist', 'Colachie1', 'oguzalbyrk', 'EcuadorHello', 'rabbits_fc', 'CARDlGAN', 'Mkhristina', 'Mulambeiro2', 'hager_skyler', 'VeeJosie', '_SUMIT2811', 'hk_harikv', 'cas05271', 'hbrrison', 'SamuraiDizzeus', 'FaithHaleem', 'Michael89704952', 'Philipkalu10', 'rahulec100', 'JusticiarThe', 'alejand59006581', 'LnQ0EIJyecd2Wwe', 'Pioneer_James', 'EthanHa82225896', 'Sam09396719', 'ReyinaFalangie', 'BigTechChannel', 'LAUengineering', 'ryan_dobrick20', 'GrigAndy', 'MBG00973784', 'VivoGala', 'cjhynes06', 'manuelfortis', 'rainermiles18', 'ilias_022', 'MaxwellSapp', 'tftsuchiya', 'eelwardanyy', 'wmhafizhusain', 'aaronmcgroder', 'fx4rn', 'Emil_DK04', 'tfuefan54', 'AraConnoisseur', 'Emileysmom09', 'HenryGonzalezM7', 'ExploringEveMFC', 'HannaMHansen', 'freebullshit90s', 'BroTonydillon', 'YHefiane', 'sarathsahu', 'MrSirjohny123', 'HvdraMusic', 'ptitjardin44', 'DebraDuffy11', 'kozmik0607', 'TheWatc07150812', 'RaulRiosOr', 'thetobykendrick', 'noBodyWasFresh', 'RhysDinnis', 'OxPhotoJim', 'mattiNacimiento', 'CLos501', 'bcuriel5', 'RajSadafule', 'faithunedited1', 'T_S_D_T_17', 'suswhitevans', 'technikfreak8', 'mrsSarahLanz', 'AdrienJavier1', 'ERIC1507', 'venturidanilo82', 'MongoosePower17', 'imaritzai', 'pelaoabocao', 'EminAba21', 'glpratyush', 'G_e_r_a_l_dh', 'trentonyounts', 'ascottpryde', 'MrThompsonLeads', 'DMuzelenga', 'cshumphries', 'SatinderSehra', 'neomoorgul', 'ledesma_jk', 'xanderyg', 'LNOMS', 'BouttellAnthony', 'Sandy10385504', 'newoceanx', 'Mubassher5', 'Shahradjan', 'ElijahWharton2', 'hot_garnish', 'Vbtransportnlo1', 's_rambo14', 'laurasalasz', 'thalveld', 'bryt_edem', 'LEON96984612', 'SefaKervank', 'KABAN____', 'LimestonAtelier', 'Andres18875531', 'NewsJoker2', 'cherry_sugar', 'MrRenzulli', 'Mein_heart', 'DukeVSO', 'TFtophy', 'Nile72636893', 'yanagisofficial', 'orlcosta56']

# with open('/user_id_names_inprogress.csv',newline='\n') as f:
# 	reader = csv.reader(f)
# 	user_data = list(reader)

# user_name_pos = []  
# for i in user_data:
# 	user_name_pos.append(i[1]) 

def get_neighbours(screenname):
	data_dict = {}
	data_dict[screenname] = {}
	followee = []
	followers = []
	count = 0
	count_inner=0
	#print("In get_neighbours...")
	try:
		for user in tweepy.Cursor(api.followers, screen_name=screenname).items():
		#(int(user.followers_count)+int(user.friends_count) > 500)
			#print("Initializing the count...")
			
			if ((user.screen_name not in user_name_neg)):

				#print("Found an user.........")
				if  (user.protected == False) and (int(user.statuses_count) > 0):
					screen_name_user, user_tweets = get_all_tweets(user.screen_name)

					data_dict[screenname][user.screen_name] = {}
					data_dict[screenname][user.screen_name]['tweets']=user_tweets
					data_dict[screenname][user.screen_name]['location']=user.location
					count += 1

					for sc_user in tweepy.Cursor(api.followers, screen_name=screen_name_user).items(200):
						#print("Finding followers of follower.....")
						try:	
							if (sc_user.protected == False) and (int(sc_user.statuses_count) >= 200) and (int(user.followers_count)<=1000):
								follower_user, follower_user_tweets = get_all_tweets(sc_user.screen_name)
								data_dict[screenname][screen_name_user][follower_user] = {}
								data_dict[screenname][screen_name_user][follower_user]['tweets']=follower_user_tweets
								data_dict[screenname][screen_name_user][follower_user]['location']=sc_user.location
								count_inner+= 1
						except tweepy.error.TweepError:
							print(tweepy.error.TweepError)
							pass
					print("followers collected: ", count)
					print("Inner followers collected: ",count_inner)
					with open('tweet_data_user_id_approach2.json', 'w') as outfile:
						json.dump(data_dict, outfile)
	except tweepy.error.TweepError:
		print(tweepy.error.TweepError)
		pass

	with open('approach_FORGRAPH_tweets_data.json', 'w') as outfile:
		json.dump(data_dict, outfile)

	print("Finished running the script. :)")

def get_all_tweets(screen_name):
	try:
	#initialize a list to hold all the tweepy Tweets#initialize a list to hold all the tweepy Tweets
		alltweets = []	
		
		#make initial request for most recent tweets (200 is the maximum allowed count)
		new_tweets = api.user_timeline(screen_name = screen_name,count=200, lang='en')
		
		#save most recent tweets
		alltweets.extend(new_tweets)
		#save the id of the oldest tweet less one
		if len(alltweets)>0:
			oldest = alltweets[-1].id - 1
		#keep grabbing tweets until there are no tweets left to grab
			while len(alltweets) < 200 and len(new_tweets) > 0:
				# print("getting tweets before %s" % (oldest))
				#all subsiquent requests use the max_id param to prevent duplicates
				new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest, lang='en')
				#save most recent tweets
				alltweets.extend(new_tweets)
				#update the id of the oldest tweet less one
				oldest = alltweets[-1].id - 1
				
				# print("...%s tweets downloaded so far" % (len(alltweets)))

		#transform the tweepy tweets into a 2D array that will populate the csv	
		outtweets = [[tweet.id_str, tweet.text] for tweet in alltweets if tweet.lang == "en"]
		print(screen_name)
		return screen_name, outtweets

	except tweepy.error.TweepError:
		print(tweepy.error.TweepError)
		return screen_name, "error"

if __name__ == '__main__':
	#pass in the username of the account you want to download
	# user_ids = ['FoodandTravelEd','nytimes','premierleague','MTV','facebook','eBay','parenting']
	# for i in user_ids:
	get_neighbours('tesla')
	pass
# Out:
# kenziemelonn
# 16thOfOctober
# alexandfurr
# mangocaldwell21
# FletcherFans1
# Shi_AnneSkiy
# solalexasch
# DerekCrumer
# IsaacConaway
# haciendastl
# __emilyatkinson
# brittaanytitov
# lancevantine
# JesusSaves_Broo
# BigJGlose
# NickDavenport17
# jiillly_beaan
# Casa_De_Burgess
# Young__Dirty
# ErnestChitiza
# rliebhart1975
# Sugar_renae
# PapaChris96
# dailypotatonews
# 15HannahNicole
# allielee1999
# _snellymaitland
# Thinson20_2
# MeowCaw
# JosephRind
# ReemaMFgibbs
# KaitieAdkins
# shrimpy004
# aubs98
# HookedOnGoT
# DevonFlemingo
# Taylorszek
# LucasZurliene
# OnlineEZYincome
# KatyPerrySlayer
# Hanky_Spank
# amandaleeann18
# GraceGendron
# kyndra_morgan
# KNasteeee
# SierraEdmond_24
# Hunter_Kelemen
# Brandon23L
# Sha_Keel_23
# TobiWanTaylor
# nyadorsey
# _panipopo_
# j_harris21
# em_cookiee
# t_dawg129
# hines_Lin
# Fc_Brady
# Kassidyy97
# alexeatsit
# smithcalvin69
# Briyonce_96
# BrittneyFranek
# followers collected:  1
# Inner followers collected:  61
# AguonJojo
# ...
